# %% [markdown]
# # Chlorophyll levels in the Westerschlde
# This notebook is an exercise in trying to predict primary production in the Westerscheldt from measurements of other data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as sps
import matplotlib.pyplot as plt
import pylab
from sklearn.ensemble import RandomForestRegressor
rands = 142
# %matplotlib inline
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
def corrfunc(x, y, **kws):
    (r, p) = sps.pearsonr(x, y)
    ax = plt.gca()
    ax.annotate("r = {:.2f}".format(r),
                xy=(.1, .9), xycoords=ax.transAxes)
    ax.annotate("p = {:.3f}".format(p),
                xy=(.4, .9), xycoords=ax.transAxes)

def make_ts(var):
    return pd.Timestamp(var)

def make_datetime(var):
    return pd.Timestamp(var[0:10])

def make_month(var):
    return var.month

def make_hour(var):
    return var.hour

# %%
def make_station_df(df, station, threshold = 100):
    '''this function mades a Westerschelde station based on the proven workflow'''
    df = df[df['station'] == station]
    # df.drop(['latitude', 'longitude'], axis = 1, inplace = True)
    dfs_dict = {}
    threshold = 100
    try:
        df['date'] = df['datetime'].apply(make_datetime)
        df['datetime'] = df['datetime'].apply(make_ts)
        df['month'] = df['datetime'].apply(make_month)
        df['hour'] = df['datetime'].apply(make_hour)
        print('should not be longer than: ' + str(len(df['datetime'].unique())))
    except:
        pass
    # repurcussions of choosing date vs datetime as index...
    dff = pd.DataFrame(df['datetime'].unique())
    #dff = pd.DataFrame(df['date'].unique())

    dff['dummy'] = np.ones(len(dff))
    dff.set_index(0, inplace = True)

    for sub in df['aggName'].unique():
        dfs = df[df['aggName'] == sub][['datetime','value']]
        dfs.set_index('datetime', inplace = True)
        #dfs.set_index('date', inplace = True)
        dfs.sort_index(inplace = True)
        dfs.rename(columns = {'value' : sub}, inplace = True)
        if len(dfs) > threshold:
            print(sub)
            #print(len(dfs.index),len(dfs.index.unique()))
            if len(dfs.index) != len(dfs.index.unique()):
                # for each unique duplicated index, we assign the unique index
                # to be equal to he average of values at that index
                # there is so far no explanation for the duplicates
                for ind in dfs[dfs.index.duplicated()].index.unique():
                    vals = dfs.loc[ind]
                    vals[sub] = np.mean(vals[sub])
                    # now duplicate indicies will all have the same value, 
                    # and we can simply take the first
            dfs = dfs[~dfs.index.duplicated(keep='first')]
            dff = pd.concat((dff,dfs), axis = 1, ignore_index = False)
            dfs_dict[sub] = dfs
    return dff

# %%
station_train = 'Terneuzen boei 20'
station_test = 'Vlissingen'

# %%
df = pd.read_csv('../data/standarddata/Scheldemonitor_ASCII.csv')
df = df[df['station'] == station_train]
df.drop(['latitude', 'longitude'], axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['station', 'depth', 'datetime', 'aggName', 'value', 'unit',
#        'dataprovider'],
#       dtype='object')

# %%
df['aggName'].unique()
# Out:
# array(['SPM', 'tP', 'Temp', 'KjN', 'Sal', 'NO2', 'NOX', 'Si', 'dP', 'O2',
#        'DOC', 'NH4', 'COD', 'NO3', 'SO4', 'pN', 'POC', 'PO4', 'dN',
#        'fpPO4', 'pSi', 'pPO4', 'Transparence', 'E', 'chlfa'], dtype=object)

# %% [markdown]
# Here we try to see if there is any information we can gather as to the source of the duplicates. <br>
# for this we look at the unedited dataframe for the paramter tP at the values found at the second index which occurs more than once

# %%
tmp = df[df['aggName'] == 'tP']
tmp.set_index('datetime', inplace = True)
tmp.loc[tmp[tmp.index.duplicated()].index.unique()[1]]
# Out:
#                                 station  depth aggName  value   unit  \
# datetime
# 2000-08-21T10:32:00Z  Terneuzen boei 20    1.0      tP  0.600  mgP_l
# 2000-08-21T10:32:00Z  Terneuzen boei 20    1.0      tP  0.139  mgP_l
#
#                                dataprovider
# datetime
# 2000-08-21T10:32:00Z  RWS - Rijkswaterstaat
# 2000-08-21T10:32:00Z  RWS - Rijkswaterstaat

# %% [markdown]
# Everything is identical, even the time, except for the value. <br>
# Is this the case for other parameters?

# %%
tmp = df[df['aggName'] == 'NO3']
tmp.set_index('datetime', inplace = True)
tmp.loc[tmp[tmp.index.duplicated()].index.unique()[1]]
# Out:
#                                 station  depth aggName  value   unit  \
# datetime
# 2000-08-21T10:32:00Z  Terneuzen boei 20    1.0     NO3   7.10  mgN_l
# 2000-08-21T10:32:00Z  Terneuzen boei 20    1.0     NO3   1.39  mgN_l
#
#                                dataprovider
# datetime
# 2000-08-21T10:32:00Z  RWS - Rijkswaterstaat
# 2000-08-21T10:32:00Z  RWS - Rijkswaterstaat

# %%
df
# Out:
#                   station  depth              datetime aggName  value   unit  \
# 4       Terneuzen boei 20    1.0  1983-04-05T11:33:00Z     SPM  26.00   mg_l
# 9       Terneuzen boei 20    1.0  1977-04-25T11:28:00Z      tP   0.26  mgP_l
# 10      Terneuzen boei 20    1.0  1977-05-09T12:00:00Z      tP   0.25  mgP_l
# 11      Terneuzen boei 20    1.0  1977-05-23T10:50:00Z      tP   0.17  mgP_l
# 343     Terneuzen boei 20    1.0  1987-09-07T09:47:00Z      tP   0.39  mgP_l
# 344     Terneuzen boei 20    NaN  1988-03-17T08:12:00Z    Temp   5.50      C
# 352     Terneuzen boei 20    1.0  1990-01-29T08:38:00Z     KjN   0.78  mgN_l
# 360     Terneuzen boei 20    1.0  2000-06-20T02:00:00Z      tP   0.50  mgP_l
# 361     Terneuzen boei 20    1.0  2000-07-24T02:00:00Z      tP   0.20  mgP_l
# 362     Terneuzen boei 20    1.0  2000-08-21T10:32:00Z      tP   0.60  mgP_l
# 382     Terneuzen boei 20    1.0  1977-04-18T09:45:00Z      tP   0.39  mgP_l
# 383     Terneuzen boei 20    1.0  2013-11-04T15:21:00Z     Sal  25.40    PSU
# 384     Terneuzen boei 20    1.0  2012-12-03T18:19:00Z     Sal  26.30    PSU
# 387     Terneuzen boei 20    1.0  2000-03-14T12:39:00Z      tP   0.20  mgP_l
# 402     Terneuzen boei 20    1.0  1993-09-06T09:49:00Z     Sal  27.91    PSU
# 403     Terneuzen boei 20    1.0  1993-10-04T09:19:00Z     Sal  26.17    PSU
# 404     Terneuzen boei 20    1.0  1991-12-09T06:28:00Z     Sal  25.40    PSU
# 405     Terneuzen boei 20    1.0  1992-03-09T09:40:00Z     Sal  24.27    PSU
# 406     Terneuzen boei 20    1.0  1993-03-01T11:09:00Z     Sal  22.63    PSU
# 407     Terneuzen boei 20    1.0  1993-03-29T10:45:00Z     Sal  23.33    PSU
# 408     Terneuzen boei 20    1.0  1993-04-26T09:17:00Z     Sal  25.31    PSU
# 409     Terneuzen boei 20    1.0  1993-05-24T09:27:00Z     Sal  25.92    PSU
# 410     Terneuzen boei 20    1.0  1993-06-21T09:32:00Z     Sal  25.47    PSU
# 411     Terneuzen boei 20    1.0  1993-07-12T12:31:00Z     Sal  27.44    PSU
# 412     Terneuzen boei 20    1.0  1993-08-09T10:55:00Z     Sal  27.09    PSU
# 413     Terneuzen boei 20    1.0  1993-11-08T12:04:00Z     Sal  25.86    PSU
# 414     Terneuzen boei 20    1.0  1993-12-06T09:00:00Z     Sal  24.82    PSU
# 415     Terneuzen boei 20    1.0  1994-01-04T11:09:00Z     Sal  16.02    PSU
# 416     Terneuzen boei 20    1.0  1994-02-01T09:36:00Z     Sal  16.48    PSU
# 417     Terneuzen boei 20    1.0  1994-02-28T08:15:00Z     Sal  20.97    PSU
# ...                   ...    ...                   ...     ...    ...    ...
# 180077  Terneuzen boei 20    1.0  2013-07-17T10:37:00Z   chlfa  10.00   ug_l
# 180078  Terneuzen boei 20    1.0  2013-08-15T10:08:00Z   chlfa   6.00   ug_l
# 180079  Terneuzen boei 20    1.0  2013-09-12T08:31:00Z   chlfa   4.00   ug_l
# 180080  Terneuzen boei 20    1.0  2013-10-07T17:52:00Z   chlfa   4.90   ug_l
# 180081  Terneuzen boei 20    1.0  2013-11-04T15:21:00Z   chlfa   2.30   ug_l
# 180082  Terneuzen boei 20    1.0  2013-12-03T15:02:00Z   chlfa   1.40   ug_l
# 180083  Terneuzen boei 20    1.0  2013-12-30T13:29:00Z   chlfa   1.70   ug_l
# 180084  Terneuzen boei 20    1.0  2016-01-11T16:02:00Z   chlfa   1.80   ug_l
# 180085  Terneuzen boei 20    1.0  2016-02-08T15:12:00Z   chlfa   1.25   ug_l
# 180086  Terneuzen boei 20    1.0  2016-03-07T14:14:00Z   chlfa   1.37   ug_l
# 180087  Terneuzen boei 20    1.0  2016-03-21T14:42:00Z   chlfa   4.10   ug_l
# 180088  Terneuzen boei 20    1.0  2016-04-20T15:34:00Z   chlfa   8.10   ug_l
# 180089  Terneuzen boei 20    1.0  2016-05-18T14:31:00Z   chlfa  33.00   ug_l
# 180090  Terneuzen boei 20    1.0  2016-06-13T10:58:00Z   chlfa   5.70   ug_l
# 180091  Terneuzen boei 20    1.0  2016-07-13T10:56:00Z   chlfa   2.80   ug_l
# 180092  Terneuzen boei 20    1.0  2016-08-11T10:00:00Z   chlfa   2.80   ug_l
# 180093  Terneuzen boei 20    1.0  2016-09-05T17:41:00Z   chlfa   5.90   ug_l
# 180094  Terneuzen boei 20    1.0  2016-10-03T17:35:00Z   chlfa   6.00   ug_l
# 180095  Terneuzen boei 20    1.0  2016-10-18T17:24:00Z   chlfa   2.30   ug_l
# 180096  Terneuzen boei 20    1.0  2016-12-01T15:26:00Z   chlfa   1.07   ug_l
# 180097  Terneuzen boei 20    1.0  2016-12-29T14:00:00Z   chlfa   1.54   ug_l
# 180098  Terneuzen boei 20    1.0  2015-02-10T19:03:00Z   chlfa   1.15   ug_l
# 180099  Terneuzen boei 20    1.0  2015-04-21T17:50:00Z   chlfa  11.00   ug_l
# 180100  Terneuzen boei 20    1.0  2015-05-19T17:04:00Z   chlfa   6.90   ug_l
# 180101  Terneuzen boei 20    1.0  2015-06-17T16:39:00Z   chlfa   7.40   ug_l
# 180102  Terneuzen boei 20    1.0  2015-07-13T14:24:00Z   chlfa  12.90   ug_l
# 180103  Terneuzen boei 20    1.0  2015-08-10T13:00:00Z   chlfa   3.30   ug_l
# 180104  Terneuzen boei 20    1.0  2015-09-09T14:36:00Z   chlfa   2.70   ug_l
# 180105  Terneuzen boei 20    1.0  2015-11-17T18:36:00Z   chlfa   2.90   ug_l
# 180106  Terneuzen boei 20    1.0  2015-12-14T16:57:00Z   chlfa   2.00   ug_l
#
#                  dataprovider
# 4       RWS - Rijkswaterstaat
# 9       RWS - Rijkswaterstaat
# 10      RWS - Rijkswaterstaat
# 11      RWS - Rijkswaterstaat
# 343     RWS - Rijkswaterstaat
# 344     RWS - Rijkswaterstaat
# 352     RWS - Rijkswaterstaat
# 360     RWS - Rijkswaterstaat
# 361     RWS - Rijkswaterstaat
# 362     RWS - Rijkswaterstaat
# 382     RWS - Rijkswaterstaat
# 383     RWS - Rijkswaterstaat
# 384     RWS - Rijkswaterstaat
# 387     RWS - Rijkswaterstaat
# 402     RWS - Rijkswaterstaat
# 403     RWS - Rijkswaterstaat
# 404     RWS - Rijkswaterstaat
# 405     RWS - Rijkswaterstaat
# 406     RWS - Rijkswaterstaat
# 407     RWS - Rijkswaterstaat
# 408     RWS - Rijkswaterstaat
# 409     RWS - Rijkswaterstaat
# 410     RWS - Rijkswaterstaat
# 411     RWS - Rijkswaterstaat
# 412     RWS - Rijkswaterstaat
# 413     RWS - Rijkswaterstaat
# 414     RWS - Rijkswaterstaat
# 415     RWS - Rijkswaterstaat
# 416     RWS - Rijkswaterstaat
# 417     RWS - Rijkswaterstaat
# ...                       ...
# 180077  RWS - Rijkswaterstaat
# 180078  RWS - Rijkswaterstaat
# 180079  RWS - Rijkswaterstaat
# 180080  RWS - Rijkswaterstaat
# 180081  RWS - Rijkswaterstaat
# 180082  RWS - Rijkswaterstaat
# 180083  RWS - Rijkswaterstaat
# 180084  RWS - Rijkswaterstaat
# 180085  RWS - Rijkswaterstaat
# 180086  RWS - Rijkswaterstaat
# 180087  RWS - Rijkswaterstaat
# 180088  RWS - Rijkswaterstaat
# 180089  RWS - Rijkswaterstaat
# 180090  RWS - Rijkswaterstaat
# 180091  RWS - Rijkswaterstaat
# 180092  RWS - Rijkswaterstaat
# 180093  RWS - Rijkswaterstaat
# 180094  RWS - Rijkswaterstaat
# 180095  RWS - Rijkswaterstaat
# 180096  RWS - Rijkswaterstaat
# 180097  RWS - Rijkswaterstaat
# 180098  RWS - Rijkswaterstaat
# 180099  RWS - Rijkswaterstaat
# 180100  RWS - Rijkswaterstaat
# 180101  RWS - Rijkswaterstaat
# 180102  RWS - Rijkswaterstaat
# 180103  RWS - Rijkswaterstaat
# 180104  RWS - Rijkswaterstaat
# 180105  RWS - Rijkswaterstaat
# 180106  RWS - Rijkswaterstaat
#
# [12118 rows x 7 columns]

# %% [markdown]
# Yes, and the duplicate occurs on the same day. We will assume for now that it is a duplicate measurement. The numbers are quite different which is suspicious.

# %% [markdown]
# Now we will make a dataframe where the columns are features. <br>
# To do this we will make an empty data frame with indicies representing all measured times. <br>
# we will then go through each substance and make a dataframe of those times and the substance values. Following this we will concatenate this with the growing data frame.

# %%
## refactored
dff = make_station_df(df, station_train)
# Out:
# should not be longer than: 1193
# SPM
# tP
# Temp
# KjN
# Sal
# NO2
# NOX
# Si
# dP
# O2
# DOC
# NH4
# NO3
# SO4
# pN
# POC
# PO4
# dN
# pPO4
# Transparence
# E
# chlfa

# %%
dff
# Out:
#                            dummy     SPM      tP   Temp   KjN   Sal     NO2  \
# 1967-02-07 10:40:00+00:00    1.0     NaN     NaN   5.00   NaN   NaN     NaN
# 1967-02-20 12:00:00+00:00    1.0     NaN     NaN   4.00   NaN   NaN     NaN
# 1967-03-06 15:00:00+00:00    1.0     NaN     NaN   6.00   NaN   NaN     NaN
# 1967-04-05 11:00:00+00:00    1.0     NaN     NaN   7.50   NaN   NaN     NaN
# 1967-04-19 13:10:00+00:00    1.0     NaN     NaN   9.00   NaN   NaN     NaN
# 1967-05-08 15:45:00+00:00    1.0     NaN     NaN  10.50   NaN   NaN     NaN
# 1967-05-17 11:55:00+00:00    1.0     NaN     NaN  12.00   NaN   NaN     NaN
# 1967-05-31 15:10:00+00:00    1.0     NaN     NaN  14.00   NaN   NaN     NaN
# 1967-06-19 15:00:00+00:00    1.0     NaN     NaN  16.00   NaN   NaN     NaN
# 1967-07-05 10:55:00+00:00    1.0     NaN     NaN  18.50   NaN   NaN     NaN
# 1967-07-18 14:55:00+00:00    1.0     NaN     NaN  20.50   NaN   NaN     NaN
# 1967-08-02 11:10:00+00:00    1.0     NaN     NaN  20.00   NaN   NaN     NaN
# 1967-08-15 15:05:00+00:00    1.0     NaN     NaN  18.50   NaN   NaN     NaN
# 1967-08-30 15:55:00+00:00    1.0     NaN     NaN  19.00   NaN   NaN     NaN
# 1967-09-13 11:45:00+00:00    1.0     NaN     NaN  16.50   NaN   NaN     NaN
# 1967-10-02 15:25:00+00:00    1.0     NaN     NaN  16.00   NaN   NaN     NaN
# 1967-10-16 15:50:00+00:00    1.0     NaN     NaN  14.00   NaN   NaN     NaN
# 1967-10-30 12:10:00+00:00    1.0     NaN     NaN  11.00   NaN   NaN     NaN
# 1967-11-14 11:45:00+00:00    1.0     NaN     NaN   8.50   NaN   NaN     NaN
# 1967-11-28 16:45:00+00:00    1.0     NaN     NaN   7.00   NaN   NaN     NaN
# 1967-12-12 15:35:00+00:00    1.0     NaN     NaN   4.00   NaN   NaN     NaN
# 1968-01-10 11:50:00+00:00    1.0     NaN     NaN   3.50   NaN   NaN     NaN
# 1968-01-24 15:50:00+00:00    1.0     NaN     NaN   2.00   NaN   NaN     NaN
# 1968-02-07 11:50:00+00:00    1.0     NaN     NaN   3.50   NaN   NaN     NaN
# 1968-02-22 16:45:00+00:00    1.0     NaN     NaN   5.00   NaN   NaN     NaN
# 1968-03-06 15:15:00+00:00    1.0     NaN     NaN   3.00   NaN   NaN     NaN
# 1968-03-20 16:35:00+00:00    1.0     NaN     NaN   5.50   NaN   NaN     NaN
# 1968-04-09 14:50:00+00:00    1.0     NaN     NaN   7.50   NaN   NaN     NaN
# 1968-04-23 11:25:00+00:00    1.0     NaN     NaN   9.00   NaN   NaN     NaN
# 1968-05-08 15:20:00+00:00    1.0     NaN     NaN  10.50   NaN   NaN     NaN
# ...                          ...     ...     ...    ...   ...   ...     ...
# 2014-10-06 14:22:00+00:00    1.0   22.00  0.1360  17.70  0.43  25.9  0.0501
# 2014-11-03 12:09:00+00:00    1.0   81.20  0.1930  14.00  0.55  26.7  0.0113
# 2014-12-03 12:32:00+00:00    1.0   36.00  0.1560   9.12  0.53  26.0  0.0097
# 2014-12-29 08:45:00+00:00    1.0   63.50     NaN   6.38  0.55  23.6     NaN
# 2015-02-10 19:03:00+00:00    1.0   63.30  0.1750   4.29  0.47  20.3  0.0602
# 2015-03-09 17:22:00+00:00    1.0  108.00  0.2120   5.97  1.30  21.8  0.0648
# 2015-04-07 17:58:00+00:00    1.0   27.60  0.1110   8.32  0.37  22.5  0.0258
# 2015-04-21 17:50:00+00:00    1.0   63.60  0.1190  10.80  0.47  23.6  0.0192
# 2015-05-19 17:04:00+00:00    1.0   54.70  0.0780  13.80  0.57  25.1  0.0213
# 2015-06-17 16:39:00+00:00    1.0   63.90  0.1420  16.90  0.61  26.8  0.0133
# 2015-07-13 14:24:00+00:00    1.0   23.40  0.0926  19.70  0.76  26.8  0.0157
# 2015-08-10 13:00:00+00:00    1.0   26.10  0.0972  20.10  0.64  28.1  0.0335
# 2015-09-09 14:36:00+00:00    1.0   13.80  0.1330  18.10  0.39  26.8  0.0524
# 2015-10-19 19:47:00+00:00    1.0   44.70  0.1680    NaN  0.55   NaN  0.0175
# 2015-11-17 18:36:00+00:00    1.0   48.90  0.1160  12.50  0.41  27.8  0.0174
# 2015-12-14 16:57:00+00:00    1.0   68.20  0.1860   8.62  0.39  24.7  0.0125
# 2016-01-11 16:02:00+00:00    1.0  128.00  0.1860    NaN  0.66   NaN  0.0084
# 2016-02-08 15:12:00+00:00    1.0   96.20  0.1860   7.00  0.56  22.2  0.0163
# 2016-03-07 14:14:00+00:00    1.0    5.72  0.0948   6.13  0.55  18.7  0.0454
# 2016-03-21 14:42:00+00:00    1.0   77.10  0.0911   6.59  0.58  20.9  0.0332
# 2016-04-20 15:34:00+00:00    1.0   46.70  0.1140  10.90  0.37  22.1  0.0205
# 2016-05-18 14:31:00+00:00    1.0   51.00  0.1430  14.10  0.61  24.5  0.0097
# 2016-06-13 10:58:00+00:00    1.0   25.30  0.0870  17.30  1.70  23.0  0.0278
# 2016-07-13 10:56:00+00:00    1.0   34.20  0.1260  19.00  0.22  21.8  0.0363
# 2016-08-11 10:00:00+00:00    1.0   27.80  0.1350  19.60  0.78  23.6  0.0417
# 2016-09-05 17:41:00+00:00    1.0   30.20  0.1380  20.70  1.10  25.6  0.0320
# 2016-10-03 17:35:00+00:00    1.0   36.50  0.1270  17.80  0.55  27.6  0.0219
# 2016-10-18 17:24:00+00:00    1.0  340.00  0.2200  14.50  0.57  28.3  0.0196
# 2016-12-01 15:26:00+00:00    1.0   62.80  0.1570   7.56  0.67  25.9  0.0165
# 2016-12-29 14:00:00+00:00    1.0   32.80  0.1300   6.47  0.46  24.9  0.0170
#
#                              NOX     Si      dP  ...      NO3         SO4  \
# 1967-02-07 10:40:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-02-20 12:00:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-03-06 15:00:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-04-05 11:00:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-04-19 13:10:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-05-08 15:45:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-05-17 11:55:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-05-31 15:10:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-06-19 15:00:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-07-05 10:55:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-07-18 14:55:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-08-02 11:10:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-08-15 15:05:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-08-30 15:55:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-09-13 11:45:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-10-02 15:25:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-10-16 15:50:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-10-30 12:10:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-11-14 11:45:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-11-28 16:45:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1967-12-12 15:35:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1968-01-10 11:50:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1968-01-24 15:50:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1968-02-07 11:50:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1968-02-22 16:45:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1968-03-06 15:15:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1968-03-20 16:35:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1968-04-09 14:50:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1968-04-23 11:25:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# 1968-05-08 15:20:00+00:00    NaN    NaN     NaN  ...      NaN         NaN
# ...                          ...    ...     ...  ...      ...         ...
# 2014-10-06 14:22:00+00:00  0.838  0.922  0.1130  ...    0.787  677.723298
# 2014-11-03 12:09:00+00:00  0.916  1.110  0.1000  ...    0.905  651.014991
# 2014-12-03 12:32:00+00:00  1.100  1.460  0.1180  ...    1.090  664.369144
# 2014-12-29 08:45:00+00:00  1.590    NaN     NaN  ...      NaN  594.259838
# 2015-02-10 19:03:00+00:00  2.130  2.560  0.1140  ...    2.070  500.780762
# 2015-03-09 17:22:00+00:00  2.140  2.420  0.0968  ...    2.070  540.843223
# 2015-04-07 17:58:00+00:00  1.950  1.740  0.0796  ...    1.920  560.874453
# 2015-04-21 17:50:00+00:00  1.450  1.140  0.0540  ...    1.430  627.645222
# 2015-05-19 17:04:00+00:00  1.230  0.788  0.0690  ...    1.210  627.645222
# 2015-06-17 16:39:00+00:00  0.926  0.534  0.0632  ...    0.913  691.077452
# 2015-07-13 14:24:00+00:00  0.845  0.436  0.0643  ...    0.829  714.447220
# 2015-08-10 13:00:00+00:00  0.824  0.694  0.0648  ...    0.790  741.155528
# 2015-09-09 14:36:00+00:00  0.862  0.773  0.1120  ...    0.810  697.754528
# 2015-10-19 19:47:00+00:00  0.864  0.906  0.1180  ...    0.847  691.077452
# 2015-11-17 18:36:00+00:00  0.876  0.984  0.0641  ...    0.859  694.415990
# 2015-12-14 16:57:00+00:00  1.370  1.600  0.1160  ...    1.360  640.999375
# 2016-01-11 16:02:00+00:00  1.520  1.830  0.1070  ...    1.510  640.999375
# 2016-02-08 15:12:00+00:00  1.850  2.150  0.1000  ...    1.830  574.228607
# 2016-03-07 14:14:00+00:00  2.210  2.430  0.0782  ...    2.170  507.457839
# 2016-03-21 14:42:00+00:00  1.900  1.920  0.0532  ...    1.860  560.874453
# 2016-04-20 15:34:00+00:00  1.700  1.340  0.0660  ...    1.680  574.228607
# 2016-05-18 14:31:00+00:00  0.986  0.102  0.0329  ...    0.976  644.337914
# 2016-06-13 10:58:00+00:00  1.100  0.513  0.0536  ...    1.070  590.921299
# 2016-07-13 10:56:00+00:00  1.390  1.280     NaN  ...    1.350  560.874453
# 2016-08-11 10:00:00+00:00  1.190  1.390  0.1060  ...    1.150  617.629606
# 2016-09-05 17:41:00+00:00  0.908  1.130  0.0946  ...    0.875  677.723298
# 2016-10-03 17:35:00+00:00  0.641  0.828  0.0967  ...    0.619  741.155528
# 2016-10-18 17:24:00+00:00  0.572  0.815  0.0706  ...    0.553  747.832605
# 2016-12-01 15:26:00+00:00  0.996  1.340  0.1000  ...    0.979  707.770144
# 2016-12-29 14:00:00+00:00  1.240  1.610  0.0941  ...    1.230  664.369144
#
#                               pN    POC     PO4      dN     pPO4  \
# 1967-02-07 10:40:00+00:00    NaN    NaN  0.1000     NaN      NaN
# 1967-02-20 12:00:00+00:00    NaN    NaN  0.1600     NaN      NaN
# 1967-03-06 15:00:00+00:00    NaN    NaN  0.1300     NaN      NaN
# 1967-04-05 11:00:00+00:00    NaN    NaN  0.1000     NaN      NaN
# 1967-04-19 13:10:00+00:00    NaN    NaN  0.0600     NaN      NaN
# 1967-05-08 15:45:00+00:00    NaN    NaN  0.1000     NaN      NaN
# 1967-05-17 11:55:00+00:00    NaN    NaN  0.1000     NaN      NaN
# 1967-05-31 15:10:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1967-06-19 15:00:00+00:00    NaN    NaN  0.2000     NaN      NaN
# 1967-07-05 10:55:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1967-07-18 14:55:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1967-08-02 11:10:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1967-08-15 15:05:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1967-08-30 15:55:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1967-09-13 11:45:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1967-10-02 15:25:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1967-10-16 15:50:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1967-10-30 12:10:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1967-11-14 11:45:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1967-11-28 16:45:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1967-12-12 15:35:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1968-01-10 11:50:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1968-01-24 15:50:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1968-02-07 11:50:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1968-02-22 16:45:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1968-03-06 15:15:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1968-03-20 16:35:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1968-04-09 14:50:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1968-04-23 11:25:00+00:00    NaN    NaN     NaN     NaN      NaN
# 1968-05-08 15:20:00+00:00    NaN    NaN     NaN     NaN      NaN
# ...                          ...    ...     ...     ...      ...
# 2014-10-06 14:22:00+00:00  0.091  0.679  0.0996  1.0800  0.02240
# 2014-11-03 12:09:00+00:00  0.259  1.940  0.0957  1.0500  0.09300
# 2014-12-03 12:32:00+00:00  0.166  1.070  0.0861  1.2700  0.03780
# 2014-12-29 08:45:00+00:00  0.214  1.450     NaN  1.8700      NaN
# 2015-02-10 19:03:00+00:00  0.242  1.730  0.1060  2.1000  0.06190
# 2015-03-09 17:22:00+00:00  0.412  2.420  0.0826  2.5000  0.11500
# 2015-04-07 17:58:00+00:00  0.148  1.100  0.1380  2.3200  0.03160
# 2015-04-21 17:50:00+00:00  0.270  1.750  0.0535  1.6700  0.06520
# 2015-05-19 17:04:00+00:00  0.195  1.420  0.0834  1.2600  0.00894
# 2015-06-17 16:39:00+00:00  0.284  2.190  0.0685  1.1100  0.07890
# 2015-07-13 14:24:00+00:00  0.134  0.931  0.0643  1.0400  0.02830
# 2015-08-10 13:00:00+00:00  0.126  1.050  0.0970  1.0700  0.03240
# 2015-09-09 14:36:00+00:00  0.079  0.628  0.1000  1.0900  0.02100
# 2015-10-19 19:47:00+00:00  0.223  1.490  0.0973  1.0100  0.05020
# 2015-11-17 18:36:00+00:00  0.162  1.570  0.0881  0.0291  0.05140
# 2015-12-14 16:57:00+00:00  0.188  2.200  0.1040  1.5600  0.06970
# 2016-01-11 16:02:00+00:00    NaN    NaN  0.0931  0.7850  0.09220
# 2016-02-08 15:12:00+00:00  0.312  2.600  0.0827  2.3400  0.08600
# 2016-03-07 14:14:00+00:00  0.113  0.954  0.0863  2.4500  0.01660
# 2016-03-21 14:42:00+00:00  0.262  2.120  0.0609  2.1100  0.03790
# 2016-04-20 15:34:00+00:00  0.307  1.420  0.0618  2.0600  0.04750
# 2016-05-18 14:31:00+00:00  0.362  1.980  0.0351  1.0000  0.11000
# 2016-06-13 10:58:00+00:00  0.112  1.010  0.0563  1.6400  0.03340
# 2016-07-13 10:56:00+00:00  0.175  1.270  0.0913  1.5300  0.03490
# 2016-08-11 10:00:00+00:00  0.133  0.872  0.0958  0.8190  0.02920
# 2016-09-05 17:41:00+00:00  0.156  0.988  0.0871  1.1800  0.04370
# 2016-10-03 17:35:00+00:00  0.173  1.220  0.0905  1.0100  0.03040
# 2016-10-18 17:24:00+00:00  0.881  7.280  0.0741  1.0200  0.14900
# 2016-12-01 15:26:00+00:00  0.250  1.820  0.0855  1.2400  0.05740
# 2016-12-29 14:00:00+00:00  0.148  1.420  0.0858  1.5100  0.03560
#
#                            Transparence     E  chlfa
# 1967-02-07 10:40:00+00:00           NaN   NaN    NaN
# 1967-02-20 12:00:00+00:00           NaN   NaN    NaN
# 1967-03-06 15:00:00+00:00           NaN   NaN    NaN
# 1967-04-05 11:00:00+00:00           NaN   NaN    NaN
# 1967-04-19 13:10:00+00:00           NaN   NaN    NaN
# 1967-05-08 15:45:00+00:00           NaN   NaN    NaN
# 1967-05-17 11:55:00+00:00           NaN   NaN    NaN
# 1967-05-31 15:10:00+00:00           NaN   NaN    NaN
# 1967-06-19 15:00:00+00:00           NaN   NaN    NaN
# 1967-07-05 10:55:00+00:00           NaN   NaN    NaN
# 1967-07-18 14:55:00+00:00           NaN   NaN    NaN
# 1967-08-02 11:10:00+00:00           NaN   NaN    NaN
# 1967-08-15 15:05:00+00:00           NaN   NaN    NaN
# 1967-08-30 15:55:00+00:00           NaN   NaN    NaN
# 1967-09-13 11:45:00+00:00           NaN   NaN    NaN
# 1967-10-02 15:25:00+00:00           NaN   NaN    NaN
# 1967-10-16 15:50:00+00:00           NaN   NaN    NaN
# 1967-10-30 12:10:00+00:00           NaN   NaN    NaN
# 1967-11-14 11:45:00+00:00           NaN   NaN    NaN
# 1967-11-28 16:45:00+00:00           NaN   NaN    NaN
# 1967-12-12 15:35:00+00:00           NaN   NaN    NaN
# 1968-01-10 11:50:00+00:00           NaN   NaN    NaN
# 1968-01-24 15:50:00+00:00           NaN   NaN    NaN
# 1968-02-07 11:50:00+00:00           NaN   NaN    NaN
# 1968-02-22 16:45:00+00:00           NaN   NaN    NaN
# 1968-03-06 15:15:00+00:00           NaN   NaN    NaN
# 1968-03-20 16:35:00+00:00           NaN   NaN    NaN
# 1968-04-09 14:50:00+00:00           NaN   NaN    NaN
# 1968-04-23 11:25:00+00:00           NaN   NaN    NaN
# 1968-05-08 15:20:00+00:00           NaN   NaN    NaN
# ...                                 ...   ...    ...
# 2014-10-06 14:22:00+00:00           0.7  1.86   5.40
# 2014-11-03 12:09:00+00:00           0.5   NaN   3.20
# 2014-12-03 12:32:00+00:00           0.6   NaN   1.49
# 2014-12-29 08:45:00+00:00           0.5   NaN   1.63
# 2015-02-10 19:03:00+00:00           0.6   NaN   1.15
# 2015-03-09 17:22:00+00:00           0.1  6.00   2.40
# 2015-04-07 17:58:00+00:00           0.4  2.68   4.40
# 2015-04-21 17:50:00+00:00           0.5   NaN  11.00
# 2015-05-19 17:04:00+00:00           0.7  2.34   6.90
# 2015-06-17 16:39:00+00:00           0.7  3.77   7.40
# 2015-07-13 14:24:00+00:00           0.6  0.00  12.90
# 2015-08-10 13:00:00+00:00           0.5   NaN   3.30
# 2015-09-09 14:36:00+00:00           0.8  1.39   2.70
# 2015-10-19 19:47:00+00:00           NaN   NaN   1.80
# 2015-11-17 18:36:00+00:00           0.4   NaN   2.90
# 2015-12-14 16:57:00+00:00           0.7  0.66   2.00
# 2016-01-11 16:02:00+00:00           NaN   NaN   1.80
# 2016-02-08 15:12:00+00:00           0.3  2.58   1.25
# 2016-03-07 14:14:00+00:00           0.4   NaN   1.37
# 2016-03-21 14:42:00+00:00           0.2  5.10   4.10
# 2016-04-20 15:34:00+00:00           1.0  2.27   8.10
# 2016-05-18 14:31:00+00:00           0.3  2.40  33.00
# 2016-06-13 10:58:00+00:00           0.8  1.49   5.70
# 2016-07-13 10:56:00+00:00           0.5   NaN   2.80
# 2016-08-11 10:00:00+00:00           0.6   NaN   2.80
# 2016-09-05 17:41:00+00:00           1.1  2.18   5.90
# 2016-10-03 17:35:00+00:00           0.9  2.85   6.00
# 2016-10-18 17:24:00+00:00           0.7  1.66   2.30
# 2016-12-01 15:26:00+00:00           0.7  1.92   1.07
# 2016-12-29 14:00:00+00:00           0.6  1.83   1.54
#
# [1193 rows x 23 columns]

# %% [markdown]
# If we use all of these features, how many data points do we have?

# %%
len(dff.dropna(axis = 0))
# Out:
# 54

# %% [markdown]
# This is too few points. We need to remove some objects. Let's sort by richness of data.

# %%
np.array([100 * dff.isnull().sum()/len(dff)])
# Out:
# array([[ 0.        , 43.6714166 , 53.98155909, 22.9673093 , 67.97988265,
#         58.59178541, 45.85079631, 32.43922883, 41.82732607, 73.67979883,
#         24.30846605, 61.6093881 , 27.07460184, 45.85079631, 91.19865884,
#         73.34450964, 62.69907795, 37.13327745, 73.26068734, 73.34450964,
#         54.98742666, 83.57082984, 53.64626991]])

# %%
features = pd.Series(np.array(dff.isnull().sum()/len(dff)), list(dff.columns))

# %%
features = features.sort_values()

# %%
features.plot.bar()
plt.ylabel('% of null point')
# Out:
# Text(0,0.5,'% of null point')

# %% [markdown]
# Now we select features based on a richness threshold and check resulting richness. We will set the threhsold to be those where more than 60% of days are non NULL.

# %%
drop_features = features[features > 0.6].index
prplt = sns.pairplot(dff.drop(drop_features, axis = 1).dropna())
prplt.map(corrfunc)
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:3021: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:5277: RuntimeWarning: invalid value encountered in less
#   x = np.where(x < 1.0, x, 1.0)  # if x > 1 then return 1.0

# %%
prplt.savefig('pairplot.png', dpi = 800)

# %%
dff['chlfa'].plot(label = 'original series')
plt.plot(dff.drop(drop_features, axis = 1).dropna()['chlfa'], '.',label = 'cleaned, feature reduced')
plt.legend()
plt.title('chlorophyll-a')
# Out:
# Text(0.5,1,'chlorophyll-a')

# %% [markdown]
# Now we will try a random forest regressor

# %%
rf = RandomForestRegressor(n_estimators=1000, max_depth = 5, random_state = rands)

# %%
Y_test = dff.drop(drop_features, axis = 1).dropna().pop('chlfa')

# %%
X_test = dff.drop(drop_features, axis = 1).dropna().drop(['chlfa','dummy'], axis = 1)

# %%
rf.fit(X_test, Y_test)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=5,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=None,
#            oob_score=False, random_state=142, verbose=0, warm_start=False)

# %%
feature_importance_data = []

for feature_name, feature_importance in zip(X_test.columns, rf.feature_importances_):
    feature_importance_data.append({'feature' : feature_name, 'importance' : feature_importance})
feature_importance_data = pd.DataFrame(feature_importance_data)

plt.figure(2)
ax = feature_importance_data.sort_values(by = 'importance').plot(kind = 'barh', y = 'importance', x = 'feature')

# %%
rf.feature_importances_
# Out:
# array([0.0534774 , 0.03151407, 0.06909912, 0.05030853, 0.01738399,
#        0.06173989, 0.25496125, 0.07716763, 0.07098054, 0.04777116,
#        0.25476875, 0.01082766])

# %%
features.index
# Out:
# Index(['dummy', 'Temp', 'O2', 'NH4', 'NOX', 'PO4', 'Si', 'SPM', 'NO3', 'NO2',
#        'chlfa', 'tP', 'Transparence', 'Sal', 'DOC', 'POC', 'KjN', 'dN', 'pN',
#        'pPO4', 'dP', 'E', 'SO4'],
#       dtype='object')
